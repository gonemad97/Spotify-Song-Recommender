# %%
import pickle
import pandas as pd

with open('spotify_dataset.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#       energy  danceability  acousticness  instrumentalness  mode  liveness  \
# 0      0.583         0.833       0.01510          0.000000     0    0.1100
# 1      0.477         0.673       0.53800          0.339000     1    0.1350
# 2      0.684         0.888       0.02290          0.000000     1    0.4580
# 3      0.461         0.851       0.47400          0.000000     1    0.2580
# 4      0.696         0.954       0.00576          0.000498     0    0.0754
# ...      ...           ...           ...               ...   ...       ...
# 5455   0.237         0.773       0.40100          0.783000     1    0.0808
# 5456   0.373         0.638       0.29000          0.774000     1    0.2380
# 5457   0.155         0.726       0.55800          0.709000     0    0.0910
# 5458   0.294         0.406       0.61200          0.918000     1    0.4290
# 5459   0.313         0.485       0.33200          0.871000     1    0.1890
#
#       key    tempo  valence  loudness  speechiness                      id  \
# 0      11   94.033   0.4880    -7.942       0.2940  0DQ0uSMu01OFSxZ7Qcy7Zb
# 1      10  179.934   0.5090    -8.258       0.0705  72D79mMBu1fs0DbnUU7Ecq
# 2       7   84.982   0.5320    -6.360       0.2650  6aIARN0We3Rf0O2n20J8hp
# 3       8  143.974   0.6200    -7.876       0.3220  3S5dLLX6GvTJa1bwAlN4wD
# 4      10  100.036   0.4320    -7.117       0.2040  4Hpib09wXgD84w4uwTPnYD
# ...   ...      ...      ...       ...          ...                     ...
# 5455    0  142.957   0.1490   -14.617       0.2580  1QeEuSgJieIbIcYpeND3IU
# 5456    4   79.007   0.0396   -11.411       0.1500  3MYLwBjjdVbcj0M7kUGodd
# 5457   11   82.994   0.3490   -20.248       0.0665  2PQ0EBpFcm9kaT11Zz4FAB
# 5458    0   65.553   0.3860   -14.574       0.0693  0Ueq7HrYgIzQ8wcIW6Duzg
# 5459    6   81.147   0.0381   -17.544       0.3080  2mKht77kfPCde5fOCIBfSi
#
#                                                  name           artist
# 0     Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)        Lil Poppa
# 1                                     Can You Help Me             $NOT
# 2                     RNB (feat. Megan Thee Stallion)      Young Dolph
# 3                                  No Suburban, Pt. 2          Sheff G
# 4                                              Tap In         Saweetie
# ...                                               ...              ...
# 5455                                          Low Fly        TheeAgris
# 5456                                               us           Miscél
# 5457                       Flagstaff And Forest Fires   Charles Edison
# 5458                                       Levitating  Various Artists
# 5459                                               V.            Houis
#
# [5460 rows x 14 columns]

# %%
# cols = data.columns.tolist()
# cols

# %%
# cols = cols[-3:] + cols[:11]
# data = data[cols]

# %%
data_reordered = data[['id',
 'name',
 'artist',
 'energy',
 'danceability',
 'acousticness',
 'instrumentalness',
 'mode',
 'liveness',
 'key',
 'tempo',
 'valence',
 'loudness',
 'speechiness']]

# %%
data_reordered
# Out:
#                           id                                             name  \
# 0     0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1     72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2     6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3     3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4     4Hpib09wXgD84w4uwTPnYD                                           Tap In
# ...                      ...                                              ...
# 5455  1QeEuSgJieIbIcYpeND3IU                                          Low Fly
# 5456  3MYLwBjjdVbcj0M7kUGodd                                               us
# 5457  2PQ0EBpFcm9kaT11Zz4FAB                       Flagstaff And Forest Fires
# 5458  0Ueq7HrYgIzQ8wcIW6Duzg                                       Levitating
# 5459  2mKht77kfPCde5fOCIBfSi                                               V.
#
#                artist  energy  danceability  acousticness  instrumentalness  \
# 0           Lil Poppa   0.583         0.833       0.01510          0.000000
# 1                $NOT   0.477         0.673       0.53800          0.339000
# 2         Young Dolph   0.684         0.888       0.02290          0.000000
# 3             Sheff G   0.461         0.851       0.47400          0.000000
# 4            Saweetie   0.696         0.954       0.00576          0.000498
# ...               ...     ...           ...           ...               ...
# 5455        TheeAgris   0.237         0.773       0.40100          0.783000
# 5456           Miscél   0.373         0.638       0.29000          0.774000
# 5457   Charles Edison   0.155         0.726       0.55800          0.709000
# 5458  Various Artists   0.294         0.406       0.61200          0.918000
# 5459            Houis   0.313         0.485       0.33200          0.871000
#
#       mode  liveness  key    tempo  valence  loudness  speechiness
# 0        0    0.1100   11   94.033   0.4880    -7.942       0.2940
# 1        1    0.1350   10  179.934   0.5090    -8.258       0.0705
# 2        1    0.4580    7   84.982   0.5320    -6.360       0.2650
# 3        1    0.2580    8  143.974   0.6200    -7.876       0.3220
# 4        0    0.0754   10  100.036   0.4320    -7.117       0.2040
# ...    ...       ...  ...      ...      ...       ...          ...
# 5455     1    0.0808    0  142.957   0.1490   -14.617       0.2580
# 5456     1    0.2380    4   79.007   0.0396   -11.411       0.1500
# 5457     0    0.0910   11   82.994   0.3490   -20.248       0.0665
# 5458     1    0.4290    0   65.553   0.3860   -14.574       0.0693
# 5459     1    0.1890    6   81.147   0.0381   -17.544       0.3080
#
# [5460 rows x 14 columns]

# %%
data1 = data_reordered.loc[:, 'energy':'speechiness']

# %%
# import KMeans
from sklearn.cluster import KMeans,AgglomerativeClustering,Birch

# create kmeans object
kmeans = KMeans(n_clusters=5)
# fit kmeans object to data
kmeans.fit(data1)
# print location of clusters learned by kmeans object
print(kmeans.cluster_centers_)
# save new clusters for chart
y_km = kmeans.fit_predict(data1)

# # create kmeans object
# kmeans = AgglomerativeClustering(n_clusters=5)
# # fit kmeans object to data
# kmeans.fit(data1)
# # print location of clusters learned by kmeans object
# #print(kmeans.cluster_centers_)
# # save new clusters for chart
# y_km = kmeans.fit_predict(data1)

# # create kmeans object
# kmeans = Birch(n_clusters=5)
# # fit kmeans object to data
# kmeans.fit(data1)
# # print location of clusters learned by kmeans object
# #print(kmeans.cluster_centers_)
# # save new clusters for chart
# y_km = kmeans.fit_predict(data1)
# Out:
# [[ 6.32441143e-01  5.56474286e-01  2.54908709e-01  1.39886608e-01
#    6.80000000e-01  1.80762286e-01  5.22857143e+00  1.75870427e+02
#    5.33417143e-01 -7.25668381e+00  1.36665524e-01]
#  [ 6.70024948e-01  6.89912474e-01  2.15372852e-01  7.93019185e-02
#    6.31977946e-01  1.88619848e-01  5.27498277e+00  1.23924602e+02
#    5.51698484e-01 -7.10443349e+00  8.53659545e-02]
#  [ 6.43738080e-01  6.88545159e-01  2.19828652e-01  5.79677151e-02
#    6.37103336e-01  1.68898861e-01  5.34580960e+00  1.01514138e+02
#    5.36650041e-01 -6.97737998e+00  9.28917819e-02]
#  [ 6.26491545e-01  6.44179786e-01  2.47479922e-01  1.16705013e-01
#    6.70553936e-01  1.77660350e-01  5.15451895e+00  1.47101373e+02
#    4.98678523e-01 -7.23749077e+00  1.36568999e-01]
#  [ 4.95540538e-01  6.32203100e-01  4.12815787e-01  2.99036296e-01
#    5.72593801e-01  1.70638499e-01  5.43556281e+00  8.19367659e+01
#    4.74364356e-01 -9.27125285e+00  1.35165008e-01]]

# %%
from sklearn.preprocessing import StandardScaler

features = data_reordered.loc[:, 'energy':'speechiness']
cols_to_standardize = features.columns.tolist()
data_to_standardize = data_reordered[cols_to_standardize]
data_to_standardize
# #data_to_standardize = data_reordered.loc[:, 'energy':'speechiness']
scaler = StandardScaler().fit(data_to_standardize)

# Standardize the columns.
standardized_data = data_reordered.copy()
standardized_columns = scaler.transform(data_to_standardize)
standardized_data[cols_to_standardize] = standardized_columns
standardized_data = standardized_data[cols_to_standardize]

# Fit the model.
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5).fit(standardized_data[cols_to_standardize])

# # Get results.
data_reordered['cluster'] = model.predict(standardized_data)
data_reordered['cluster']
data_reordered
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                           id                                             name  \
# 0     0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1     72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2     6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3     3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4     4Hpib09wXgD84w4uwTPnYD                                           Tap In
# ...                      ...                                              ...
# 5455  1QeEuSgJieIbIcYpeND3IU                                          Low Fly
# 5456  3MYLwBjjdVbcj0M7kUGodd                                               us
# 5457  2PQ0EBpFcm9kaT11Zz4FAB                       Flagstaff And Forest Fires
# 5458  0Ueq7HrYgIzQ8wcIW6Duzg                                       Levitating
# 5459  2mKht77kfPCde5fOCIBfSi                                               V.
#
#                artist  energy  danceability  acousticness  instrumentalness  \
# 0           Lil Poppa   0.583         0.833       0.01510          0.000000
# 1                $NOT   0.477         0.673       0.53800          0.339000
# 2         Young Dolph   0.684         0.888       0.02290          0.000000
# 3             Sheff G   0.461         0.851       0.47400          0.000000
# 4            Saweetie   0.696         0.954       0.00576          0.000498
# ...               ...     ...           ...           ...               ...
# 5455        TheeAgris   0.237         0.773       0.40100          0.783000
# 5456           Miscél   0.373         0.638       0.29000          0.774000
# 5457   Charles Edison   0.155         0.726       0.55800          0.709000
# 5458  Various Artists   0.294         0.406       0.61200          0.918000
# 5459            Houis   0.313         0.485       0.33200          0.871000
#
#       mode  liveness  key    tempo  valence  loudness  speechiness  cluster
# 0        0    0.1100   11   94.033   0.4880    -7.942       0.2940        3
# 1        1    0.1350   10  179.934   0.5090    -8.258       0.0705        4
# 2        1    0.4580    7   84.982   0.5320    -6.360       0.2650        3
# 3        1    0.2580    8  143.974   0.6200    -7.876       0.3220        3
# 4        0    0.0754   10  100.036   0.4320    -7.117       0.2040        0
# ...    ...       ...  ...      ...      ...       ...          ...      ...
# 5455     1    0.0808    0  142.957   0.1490   -14.617       0.2580        2
# 5456     1    0.2380    4   79.007   0.0396   -11.411       0.1500        2
# 5457     0    0.0910   11   82.994   0.3490   -20.248       0.0665        2
# 5458     1    0.4290    0   65.553   0.3860   -14.574       0.0693        2
# 5459     1    0.1890    6   81.147   0.0381   -17.544       0.3080        2
#
# [5460 rows x 15 columns]

# %%
#including PCA with kmeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

features = data_reordered.loc[:, 'energy':'speechiness']
cols_to_standardize = features.columns.tolist()
data_to_standardize = data_reordered[cols_to_standardize]
data_to_standardize
# #data_to_standardize = data_reordered.loc[:, 'energy':'speechiness']
scaler = StandardScaler().fit(data_to_standardize)

std = scaler.fit_transform(data_to_standardize)
pca = PCA()
pca.fit(std)
pca.explained_variance_ratio_

# # Standardize the columns.
# standardized_data = data_reordered.copy()
# standardized_columns = scaler.transform(data_to_standardize)
# standardized_data[cols_to_standardize] = standardized_columns
# standardized_data = standardized_data[cols_to_standardize]

# # Fit the model.
# from sklearn.cluster import KMeans
# model = KMeans(n_clusters=5).fit(standardized_data[cols_to_standardize])

# # # Get results.
# data_reordered['cluster'] = model.predict(standardized_data)
# data_reordered['cluster']
# data_reordered
# Out:
# array([0.26289614, 0.1281139 , 0.10113728, 0.09413408, 0.08779737,
#        0.07876438, 0.07488642, 0.05967799, 0.05576476, 0.04024878,
#        0.0165789 ])

# %%
#exmplained variance ratio plot for PCA
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(range(1,12),pca.explained_variance_ratio_.cumsum(),marker='o',linestyle='--')
plt.title("Explained Variance Ratio")
plt.xlabel("Number of Componenets")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
#third step of PCA
pca = PCA(n_components=7)
pca.fit_transform(std)

score_pca = pca.transform(std)
score_pca
# Out:
# array([[-0.15185165,  2.43043712,  0.92457781, ..., -0.69743936,
#         -1.21788333,  0.83245423],
#        [ 0.7853058 , -0.58600887,  0.39586833, ..., -1.80225527,
#          1.73313892,  0.32368919],
#        [-1.09098217,  1.50041226,  0.47322962, ...,  1.72545829,
#          0.09233325,  1.82783836],
#        ...,
#        [ 4.67337838,  1.33418948,  0.56659323, ..., -0.21484814,
#          0.38542303, -0.20246166],
#        [ 3.56960175, -1.53851374,  0.17089326, ...,  3.00305976,
#          0.86719105, -0.22677126],
#        [ 3.98778354, -0.67209649,  0.91086082, ...,  0.50707673,
#         -0.47690874,  1.15987726]])

# %%
#kmeans_pca impl
kmeans_pca = KMeans(n_clusters=5,init="k-means++",random_state=42)
#kmeans_pca = KMeans(n_clusters=4,init="k-means++",random_state=42)
kmeans_pca.fit(score_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
#getting the labels in the new PCA Kmeans df
segm_kmeans = pd.concat([data_reordered.reset_index(drop=True)],axis=1)
segm_kmeans.columns.values[-7:] = ["Component 1","Component 2","Component 3","Component 4","Component 5","Component 6","Component 7"]
segm_kmeans["Segment KMeans PCA"] = kmeans_pca.labels_
segm_kmeans.head()
#segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3",3:"Cluster 4"})
segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3",3:"Cluster 4",4:"Cluster 5"})

# %%
#visualization PCA Kmeans result
# %matplotlib inline
import seaborn as sns

x_axis = segm_kmeans["Component 1"]
y_axis = segm_kmeans["Component 2"]
plt.figure(figsize=(15,15))
sns.scatterplot(x_axis,y_axis,hue = segm_kmeans["Segment"],palette = ['g','r','c','m','y'])
plt.title("Clusters by PCA Components")
plt.show()

# %%
#scatter plot of clusters
import numpy as np

data1_arr = np.array(standardized_data[cols_to_standardize])

plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(data1_arr[data_reordered['cluster']==0, 0], data1_arr[data_reordered['cluster']==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(data1_arr[data_reordered['cluster']==1, 0], data1_arr[data_reordered['cluster']==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(data1_arr[data_reordered['cluster']==2, 0], data1_arr[data_reordered['cluster']==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(data1_arr[data_reordered['cluster']==3, 0], data1_arr[data_reordered['cluster']==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(data1_arr[data_reordered['cluster']==4, 0], data1_arr[data_reordered['cluster']==4, 1], s=100, c='magenta', label ='Cluster 5')

plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], s=300, c='yellow', label = 'Centroids')
#plt.scatter(x="energy", y="danceability",data=data1_arr, s=300, c='yellow', label = 'Centroids')


plt.title('Clusters of Tracks')
plt.xlabel('Not sure X')
plt.ylabel('Not sure Y')
plt.show()

# %%
model.cluster_centers_[:, 10]
# Out:
# array([-0.19010317, -0.40177451,  0.00610719,  2.2170856 , -0.36885424])

# %%
# %matplotlib inline
import matplotlib.patches as mpatches
import seaborn as sns


data1['k-means clusters'] = kmeans.labels_

#I played with the alpha value to get a darker more readable set of points
plt.figure(figsize=(15, 10), dpi=80)
p = sns.scatterplot(x="energy", y="danceability", hue = "k-means clusters",data=data1, marker="o", alpha=1,s=200)
palette = sns.color_palette()
# class_one = mpatches.Patch(color=palette[0], label='1', alpha=0.5)
# class_two = mpatches.Patch(color=palette[1], label='2', alpha=0.5)
# class_three = mpatches.Patch(color=palette[2], label='3', alpha=0.5)
# class_four = mpatches.Patch(color=palette[3], label='4', alpha=0.5)
# class_five = mpatches.Patch(color=palette[4], label='5', alpha=0.5)
# p.legend(handles=[class_one, class_two, class_three,class_four,class_five])
#style="k-means clusters"
p

# %%
with open('new_searched_track.pkl', 'rb') as f:
    searched = pickle.load(f)

# cols = searched.columns.tolist()
# cols = cols[-3:] + cols[:11]
# cols
# searched1 = searched[cols]
# searched1
searched_track = searched[['id',
 'name',
 'artist',
 'energy',
 'danceability',
 'acousticness',
 'instrumentalness',
 'mode',
 'liveness',
 'key',
 'tempo',
 'valence',
 'loudness',
 'speechiness']]
searched_track
# Out:
#    instrumentalness  loudness  speechiness  key  energy  liveness  mode  \
# 0            0.0273    -7.908        0.252   10   0.564     0.359     0
#
#    acousticness  valence   tempo                      id  danceability  \
# 0         0.114     0.55  77.342  7eOkHIcaoUhngxxypM5Ajr         0.753
#
#               name        artist
# 0  Look At Her Now  Selena Gomez

# %%
#to see what cluster song belongs to
print(model.predict(searched_track[cols_to_standardize]))
# Out:
# [3]

# %%
#to display all songs of a particular cluster - to display songs related to searched song
data_reordered[data_reordered.cluster == 1][50:70]
# Out:
#                          id  \
# 264  2HXsIxIW4PXJI4etLWyXR9
# 266  3F5vtfqc39SVWgvRGkjb31
# 269  6u77JB6fE2luq3Z3EAcPzG
# 270  3nS9a01VvXHQriLqJYwRqG
# 271  5clAYw9wcHAUgwrE77OhnY
# 274  2YexeE3MU9eMpv5TDVPgYl
# 279  4InIuLKMwAyITc2BHXRvHR
# 280  122HHADjdXGtvpHYnzP2ys
# 282  0XiU7O1PuTnFZqG3fLq4Gy
# 288  3n1RpuGgxRqFCzDUpywWNq
# 293  6ALWLCjTGSsl6DbyD1GGdT
# 295  6YusoLOq20q8Ir33LK0whi
# 296  0JxV9dyRiKOIrTww49m3lf
# 297  4jMPZl0GrSFgbogJ0C6sNG
# 303  1XqXP90qsLbovDiOHLVIBw
# 310  00ligkpPNvTBiOrGKK5pkk
# 311  6rjF1k4tt0hI0MD3WyLriA
# 316  2q5fTRcsWQaTnuETNFNDrs
# 319  7LtCbPmbcnBqYmIVmDZPkN
# 323  67HFbeyAkneVBBwMVk84y7
#
#                                                   name             artist  \
# 264                                          Allegedly            Medhane
# 266                                         Full Hands            Medhane
# 269                                        Extravagant           Kamaiyah
# 270               DOLLAZ ON MY HEAD (feat. Young Thug)              Gunna
# 271                                             Summer          Bktherula
# 274                          Dropout (with Maxo Kream)      OMB Bloodbath
# 279                Tryna Figure Out Where My Phone At?          Zelooperz
# 280                        Attitude (feat. Young Nudy)  Deante' Hitchcock
# 282                                            october         Kahlil Blu
# 288                                Tales from the Loop      Sporting Life
# 293                                     Cops N Robbers          Key Glock
# 295  Dirty (from Insecure: Music From The HBO Origi...         Rico Nasty
# 296                           sittin at the bar - demo            Donwill
# 297                                             SKYBOX              Gunna
# 303                                      Drywall Steam        Vic Spencer
# 310                                         Rose Royce       Preservation
# 311                                          BIG FACTS         Saint Lyor
# 316                                       Pray or Prey             Ho99o9
# 319                                          Wednesday         Fly Anakin
# 323                                     My High (Edit)         Disclosure
#
#      energy  danceability  acousticness  instrumentalness  mode  liveness  \
# 264   0.826         0.470      0.000193          0.000008     1    0.4340
# 266   0.778         0.563      0.385000          0.000000     1    0.6380
# 269   0.642         0.909      0.016200          0.000000     1    0.0822
# 270   0.458         0.825      0.114000          0.000000     1    0.1020
# 271   0.573         0.444      0.006910          0.000000     1    0.1690
# 274   0.563         0.852      0.376000          0.000000     1    0.1870
# 279   0.607         0.820      0.312000          0.000000     1    0.1710
# 280   0.735         0.744      0.256000          0.000000     1    0.1690
# 282   0.890         0.773      0.036200          0.482000     1    0.0888
# 288   0.590         0.272      0.138000          0.005840     1    0.5430
# 293   0.457         0.852      0.131000          0.000000     1    0.3420
# 295   0.763         0.754      0.000052          0.000002     1    0.2750
# 296   0.755         0.392      0.417000          0.001780     1    0.1210
# 297   0.635         0.780      0.132000          0.000000     1    0.1000
# 303   0.751         0.460      0.134000          0.000000     1    0.2650
# 310   0.821         0.554      0.193000          0.019800     1    0.5260
# 311   0.612         0.904      0.017300          0.000011     1    0.0908
# 316   0.719         0.622      0.099800          0.000000     1    0.3540
# 319   0.781         0.770      0.067100          0.000000     1    0.1990
# 323   0.796         0.747      0.000411          0.002870     1    0.0366
#
#      key    tempo  valence  loudness  speechiness  cluster
# 264    1   80.268   0.4920    -7.782       0.2250        1
# 266   10  137.040   0.5760    -6.060       0.1970        1
# 269    7   93.994   0.3770    -6.717       0.1750        1
# 270    0  145.115   0.1610    -7.470       0.0577        1
# 271    5  164.289   0.1550    -7.790       0.0552        1
# 274    2  110.021   0.3280    -8.468       0.1370        1
# 279    8  138.681   0.7700    -9.426       0.1860        1
# 280    0  134.899   0.5400    -3.257       0.1120        1
# 282    1   75.497   0.3970    -4.899       0.0542        1
# 288    0  126.982   0.3640    -8.216       0.0732        1
# 293    1  138.072   0.0396    -6.711       0.0662        1
# 295    1   92.605   0.2650    -5.145       0.0831        1
# 296    7   93.452   0.5260    -7.696       0.1400        1
# 297    1  140.997   0.3710    -7.917       0.1700        1
# 303    8  108.240   0.3420    -9.127       0.1120        1
# 310    5   91.976   0.4020    -4.405       0.0382        1
# 311    1   91.594   0.4260    -5.302       0.1570        1
# 316    8  104.795   0.1130    -7.869       0.0769        1
# 319    7   90.902   0.5420    -3.482       0.2350        1
# 323    9  133.010   0.9280    -5.359       0.1150        1

# %%
#pca example 2
correlation = data_reordered.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_3f970116_cc81_11ea_96c8_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col7 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row0_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col3 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col5 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col8 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col9 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row1_col10 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col3 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col4 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row2_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col1 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col4 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col9 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row3_col10 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col3 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col8 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col9 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row5_col0 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row5_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row5_col2 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row5_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_3f970116_cc81_11ea_96c8_acde48001122row5_col4 {
#             background-color:  #5572df;
#             color:  #000000

# %%
from sklearn.preprocessing import StandardScaler
std_audio = StandardScaler().fit_transform(data_reordered[cols_to_standardize]) # normalizing the data

# %%
pca = PCA(n_components=11)
principalComponents = pca.fit_transform(std_audio)

# %%
# Plotting the variances for each PC
PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='gold')
plt.xlabel('Principal Components')
plt.ylabel('Variance %')
plt.xticks(PC)

# Putting components in a dataframe for later
PCA_components = pd.DataFrame(principalComponents)

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.3, color='gold')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()

# %%
inertias = []

# Creating 10 K-Mean models while varying the number of clusters (k)
for k in range(1,10):
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(PCA_components.iloc[:,:3])
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(range(1,10), inertias, '-p', color='gold')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
#plt.xticks(k)
plt.show()

# %%
model = KMeans(n_clusters=3)
model.fit(PCA_components.iloc[:,:2])

labels = model.predict(PCA_components.iloc[:,:2])
plt.scatter(PCA_components[0], PCA_components[1], c=labels)
plt.show()

# %%
#getting the labels in the new PCA Kmeans df
segm_kmeans = pd.concat([data_reordered.reset_index(drop=True)],axis=1)
#segm_kmeans.columns.values[-11:] = ["Component 1","Component 2","Component 3","Component 4","Component 5","Component 6","Component 7","Component 8","Component 9","Component 10","Component 11"]
segm_kmeans["Segment KMeans PCA"] = model.labels_
segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3"})
segm_kmeans.head()
# Out:
#                        id                                             name  \
# 0  0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1  72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2  6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3  3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4  4Hpib09wXgD84w4uwTPnYD                                           Tap In
#
#         artist  energy  danceability  acousticness  instrumentalness  mode  \
# 0    Lil Poppa   0.583         0.833       0.01510          0.000000     0
# 1         $NOT   0.477         0.673       0.53800          0.339000     1
# 2  Young Dolph   0.684         0.888       0.02290          0.000000     1
# 3      Sheff G   0.461         0.851       0.47400          0.000000     1
# 4     Saweetie   0.696         0.954       0.00576          0.000498     0
#
#    liveness  key    tempo  valence  loudness  speechiness  Segment KMeans PCA  \
# 0    0.1100   11   94.033    0.488    -7.942       0.2940                   1
# 1    0.1350   10  179.934    0.509    -8.258       0.0705                   2
# 2    0.4580    7   84.982    0.532    -6.360       0.2650                   1
# 3    0.2580    8  143.974    0.620    -7.876       0.3220                   1
# 4    0.0754   10  100.036    0.432    -7.117       0.2040                   1
#
#      Segment
# 0  Cluster 2
# 1  Cluster 3
# 2  Cluster 2
# 3  Cluster 2
# 4  Cluster 2

# %%
#visualization PCA Kmeans result
# %matplotlib inline
import seaborn as sns

x_axis = PCA_components[0]
y_axis = PCA_components[1]
plt.figure(figsize=(15,15))
sns.scatterplot(x_axis,y_axis,hue = segm_kmeans["Segment"],palette = ['g','r','b'])
plt.title("Clusters by PCA Components")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
std_audio = StandardScaler().fit_transform(searched_track[cols_to_standardize]) # normalizing the data
# pca = PCA(n_components=1)
principalComponents = pca.transform(std_audio)
PCA_components = pd.DataFrame(principalComponents)
print(model.predict(PCA_components.iloc[:,:2]))
# Out:
# [1]

# %%
x = segm_kmeans[segm_kmeans["Segment KMeans PCA"] == 1]
x.iloc[:, : 3]
# Out:
#                           id                                             name  \
# 0     0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 2     6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3     3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4     4Hpib09wXgD84w4uwTPnYD                                           Tap In
# 5     0qnHywpYq7D2SGMpuHEasL         Not A Rapper (feat. Lil Baby & Yo Gotti)
# ...                      ...                                              ...
# 5416  25DpSAlvzZSdYYYAq405T9                                Digital Wallpaper
# 5427  0oimP7Y3nGjmS5ZVywP35Y                                Jazzclub Solitude
# 5429  7usDnd3jQUDUTVmpsaO1rc                          Pug Life - Instrumental
# 5434  2ptWzGBVvVSDZ9mJavA9hS                                             boba
# 5450  6anXmwNsau00G1wbS5XIyO                                        Fireplace
#
#              artist
# 0         Lil Poppa
# 2       Young Dolph
# 3           Sheff G
# 4          Saweetie
# 5           42 Dugg
# ...             ...
# 5416      Lightfoot
# 5427  The Jazzister
# 5429    Bob Village
# 5434          eevee
# 5450        iamalex
#
# [2016 rows x 3 columns]
