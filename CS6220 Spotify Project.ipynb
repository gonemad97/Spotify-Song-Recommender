# %%
import pickle
import pandas as pd

with open('spotify_dataset.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.head()
# Out:
#    energy  danceability  acousticness  instrumentalness  mode  liveness  key  \
# 0   0.583         0.833       0.01510          0.000000     0    0.1100   11
# 1   0.477         0.673       0.53800          0.339000     1    0.1350   10
# 2   0.684         0.888       0.02290          0.000000     1    0.4580    7
# 3   0.461         0.851       0.47400          0.000000     1    0.2580    8
# 4   0.696         0.954       0.00576          0.000498     0    0.0754   10
#
#      tempo  valence  loudness  speechiness                      id  \
# 0   94.033    0.488    -7.942       0.2940  0DQ0uSMu01OFSxZ7Qcy7Zb
# 1  179.934    0.509    -8.258       0.0705  72D79mMBu1fs0DbnUU7Ecq
# 2   84.982    0.532    -6.360       0.2650  6aIARN0We3Rf0O2n20J8hp
# 3  143.974    0.620    -7.876       0.3220  3S5dLLX6GvTJa1bwAlN4wD
# 4  100.036    0.432    -7.117       0.2040  4Hpib09wXgD84w4uwTPnYD
#
#                                               name       artist
# 0  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)    Lil Poppa
# 1                                  Can You Help Me         $NOT
# 2                  RNB (feat. Megan Thee Stallion)  Young Dolph
# 3                               No Suburban, Pt. 2      Sheff G
# 4                                           Tap In     Saweetie

# %%
# cols = data.columns.tolist()
# cols

# %%
# cols = cols[-3:] + cols[:11]
# data = data[cols]

# %%
data_reordered = data[['id',
 'name',
 'artist',
 'energy',
 'danceability',
 'acousticness',
 'instrumentalness',
 'mode',
 'liveness',
 'key',
 'tempo',
 'valence',
 'loudness',
 'speechiness']]

# %%
data_reordered
# Out:
#                           id                                             name  \
# 0     0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1     72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2     6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3     3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4     4Hpib09wXgD84w4uwTPnYD                                           Tap In
# ...                      ...                                              ...
# 5455  1QeEuSgJieIbIcYpeND3IU                                          Low Fly
# 5456  3MYLwBjjdVbcj0M7kUGodd                                               us
# 5457  2PQ0EBpFcm9kaT11Zz4FAB                       Flagstaff And Forest Fires
# 5458  0Ueq7HrYgIzQ8wcIW6Duzg                                       Levitating
# 5459  2mKht77kfPCde5fOCIBfSi                                               V.
#
#                artist  energy  danceability  acousticness  instrumentalness  \
# 0           Lil Poppa   0.583         0.833       0.01510          0.000000
# 1                $NOT   0.477         0.673       0.53800          0.339000
# 2         Young Dolph   0.684         0.888       0.02290          0.000000
# 3             Sheff G   0.461         0.851       0.47400          0.000000
# 4            Saweetie   0.696         0.954       0.00576          0.000498
# ...               ...     ...           ...           ...               ...
# 5455        TheeAgris   0.237         0.773       0.40100          0.783000
# 5456           Miscél   0.373         0.638       0.29000          0.774000
# 5457   Charles Edison   0.155         0.726       0.55800          0.709000
# 5458  Various Artists   0.294         0.406       0.61200          0.918000
# 5459            Houis   0.313         0.485       0.33200          0.871000
#
#       mode  liveness  key    tempo  valence  loudness  speechiness
# 0        0    0.1100   11   94.033   0.4880    -7.942       0.2940
# 1        1    0.1350   10  179.934   0.5090    -8.258       0.0705
# 2        1    0.4580    7   84.982   0.5320    -6.360       0.2650
# 3        1    0.2580    8  143.974   0.6200    -7.876       0.3220
# 4        0    0.0754   10  100.036   0.4320    -7.117       0.2040
# ...    ...       ...  ...      ...      ...       ...          ...
# 5455     1    0.0808    0  142.957   0.1490   -14.617       0.2580
# 5456     1    0.2380    4   79.007   0.0396   -11.411       0.1500
# 5457     0    0.0910   11   82.994   0.3490   -20.248       0.0665
# 5458     1    0.4290    0   65.553   0.3860   -14.574       0.0693
# 5459     1    0.1890    6   81.147   0.0381   -17.544       0.3080
#
# [5460 rows x 14 columns]

# %%
data1 = data_reordered.loc[:, 'energy':'speechiness']

# %%
# import KMeans
from sklearn.cluster import KMeans,AgglomerativeClustering,Birch

# create kmeans object
kmeans = KMeans(n_clusters=5)
# fit kmeans object to data
kmeans.fit(data1)
# print location of clusters learned by kmeans object
print(kmeans.cluster_centers_)
# save new clusters for chart
y_km = kmeans.fit_predict(data1)

# # create kmeans object
# kmeans = AgglomerativeClustering(n_clusters=5)
# # fit kmeans object to data
# kmeans.fit(data1)
# # print location of clusters learned by kmeans object
# #print(kmeans.cluster_centers_)
# # save new clusters for chart
# y_km = kmeans.fit_predict(data1)

# # create kmeans object
# kmeans = Birch(n_clusters=5)
# # fit kmeans object to data
# kmeans.fit(data1)
# # print location of clusters learned by kmeans object
# #print(kmeans.cluster_centers_)
# # save new clusters for chart
# y_km = kmeans.fit_predict(data1)
# Out:
# [[ 6.43779935e-01  6.88712429e-01  2.19830555e-01  5.78790495e-02
#    6.35255890e-01  1.68759545e-01  5.34849716e+00  1.01481638e+02
#    5.37232250e-01 -6.98298294e+00  9.35577579e-02]
#  [ 6.26491545e-01  6.44179786e-01  2.47479922e-01  1.16705013e-01
#    6.70553936e-01  1.77660350e-01  5.15451895e+00  1.47101373e+02
#    4.98678523e-01 -7.23749077e+00  1.36568999e-01]
#  [ 6.69682645e-01  6.89907025e-01  2.15802347e-01  7.92473253e-02
#    6.32231405e-01  1.88557645e-01  5.27203857e+00  1.23916846e+02
#    5.51481061e-01 -7.10556612e+00  8.53287879e-02]
#  [ 6.32441143e-01  5.56474286e-01  2.54908709e-01  1.39886608e-01
#    6.80000000e-01  1.80762286e-01  5.22857143e+00  1.75870427e+02
#    5.33417143e-01 -7.25668381e+00  1.36665524e-01]
#  [ 4.95519787e-01  6.31901881e-01  4.12780993e-01  2.99764250e-01
#    5.73998365e-01  1.70840720e-01  5.43663123e+00  8.19123393e+01
#    4.73871382e-01 -9.26979150e+00  1.34648651e-01]]

# %%
from sklearn.preprocessing import StandardScaler

features = data_reordered.loc[:, 'energy':'speechiness']
cols_to_standardize = features.columns.tolist()
data_to_standardize = data_reordered[cols_to_standardize]
data_to_standardize
# #data_to_standardize = data_reordered.loc[:, 'energy':'speechiness']
scaler = StandardScaler().fit(data_to_standardize)

# Standardize the columns.
standardized_data = data_reordered.copy()
standardized_columns = scaler.transform(data_to_standardize)
standardized_data[cols_to_standardize] = standardized_columns
standardized_data = standardized_data[cols_to_standardize]

# Fit the model.
from sklearn.cluster import KMeans
model = KMeans(n_clusters=5).fit(standardized_data[cols_to_standardize])

# # Get results.
data_reordered['cluster'] = model.predict(standardized_data)
data_reordered['cluster']
data_reordered
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                           id                                             name  \
# 0     0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1     72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2     6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3     3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4     4Hpib09wXgD84w4uwTPnYD                                           Tap In
# ...                      ...                                              ...
# 5455  1QeEuSgJieIbIcYpeND3IU                                          Low Fly
# 5456  3MYLwBjjdVbcj0M7kUGodd                                               us
# 5457  2PQ0EBpFcm9kaT11Zz4FAB                       Flagstaff And Forest Fires
# 5458  0Ueq7HrYgIzQ8wcIW6Duzg                                       Levitating
# 5459  2mKht77kfPCde5fOCIBfSi                                               V.
#
#                artist  energy  danceability  acousticness  instrumentalness  \
# 0           Lil Poppa   0.583         0.833       0.01510          0.000000
# 1                $NOT   0.477         0.673       0.53800          0.339000
# 2         Young Dolph   0.684         0.888       0.02290          0.000000
# 3             Sheff G   0.461         0.851       0.47400          0.000000
# 4            Saweetie   0.696         0.954       0.00576          0.000498
# ...               ...     ...           ...           ...               ...
# 5455        TheeAgris   0.237         0.773       0.40100          0.783000
# 5456           Miscél   0.373         0.638       0.29000          0.774000
# 5457   Charles Edison   0.155         0.726       0.55800          0.709000
# 5458  Various Artists   0.294         0.406       0.61200          0.918000
# 5459            Houis   0.313         0.485       0.33200          0.871000
#
#       mode  liveness  key    tempo  valence  loudness  speechiness  cluster
# 0        0    0.1100   11   94.033   0.4880    -7.942       0.2940        2
# 1        1    0.1350   10  179.934   0.5090    -8.258       0.0705        0
# 2        1    0.4580    7   84.982   0.5320    -6.360       0.2650        2
# 3        1    0.2580    8  143.974   0.6200    -7.876       0.3220        2
# 4        0    0.0754   10  100.036   0.4320    -7.117       0.2040        1
# ...    ...       ...  ...      ...      ...       ...          ...      ...
# 5455     1    0.0808    0  142.957   0.1490   -14.617       0.2580        4
# 5456     1    0.2380    4   79.007   0.0396   -11.411       0.1500        4
# 5457     0    0.0910   11   82.994   0.3490   -20.248       0.0665        4
# 5458     1    0.4290    0   65.553   0.3860   -14.574       0.0693        4
# 5459     1    0.1890    6   81.147   0.0381   -17.544       0.3080        4
#
# [5460 rows x 15 columns]

# %%
#including PCA with kmeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

features = data_reordered.loc[:, 'energy':'speechiness']
cols_to_standardize = features.columns.tolist()
data_to_standardize = data_reordered[cols_to_standardize]
data_to_standardize
# #data_to_standardize = data_reordered.loc[:, 'energy':'speechiness']
scaler = StandardScaler().fit(data_to_standardize)

std = scaler.fit_transform(data_to_standardize)
pca = PCA()
pca.fit(std)
pca.explained_variance_ratio_

# # Standardize the columns.
# standardized_data = data_reordered.copy()
# standardized_columns = scaler.transform(data_to_standardize)
# standardized_data[cols_to_standardize] = standardized_columns
# standardized_data = standardized_data[cols_to_standardize]

# # Fit the model.
# from sklearn.cluster import KMeans
# model = KMeans(n_clusters=5).fit(standardized_data[cols_to_standardize])

# # # Get results.
# data_reordered['cluster'] = model.predict(standardized_data)
# data_reordered['cluster']
# data_reordered
# Out:
# array([0.26289614, 0.1281139 , 0.10113728, 0.09413408, 0.08779737,
#        0.07876438, 0.07488642, 0.05967799, 0.05576476, 0.04024878,
#        0.0165789 ])

# %%
#exmplained variance ratio plot for PCA
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(range(1,12),pca.explained_variance_ratio_.cumsum(),marker='o',linestyle='--')
plt.title("Explained Variance Ratio")
plt.xlabel("Number of Componenets")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
#third step of PCA
pca = PCA(n_components=7)
pca.fit_transform(std)

score_pca = pca.transform(std)
score_pca
# Out:
# array([[-0.15185165,  2.43043712,  0.92457781, ..., -0.69743936,
#         -1.21788333,  0.83245423],
#        [ 0.7853058 , -0.58600887,  0.39586833, ..., -1.80225527,
#          1.73313892,  0.32368919],
#        [-1.09098217,  1.50041226,  0.47322962, ...,  1.72545829,
#          0.09233325,  1.82783836],
#        ...,
#        [ 4.67337838,  1.33418948,  0.56659323, ..., -0.21484814,
#          0.38542303, -0.20246166],
#        [ 3.56960175, -1.53851374,  0.17089326, ...,  3.00305976,
#          0.86719105, -0.22677126],
#        [ 3.98778354, -0.67209649,  0.91086082, ...,  0.50707673,
#         -0.47690874,  1.15987726]])

# %%
#kmeans_pca impl
kmeans_pca = KMeans(n_clusters=5,init="k-means++",random_state=42)
#kmeans_pca = KMeans(n_clusters=4,init="k-means++",random_state=42)
kmeans_pca.fit(score_pca)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
#getting the labels in the new PCA Kmeans df
segm_kmeans = pd.concat([data_reordered.reset_index(drop=True)],axis=1)
segm_kmeans.columns.values[-7:] = ["Component 1","Component 2","Component 3","Component 4","Component 5","Component 6","Component 7"]
segm_kmeans["Segment KMeans PCA"] = kmeans_pca.labels_
segm_kmeans.head()
#segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3",3:"Cluster 4"})
segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3",3:"Cluster 4",4:"Cluster 5"})

# %%
#visualization PCA Kmeans result
# %matplotlib inline
import seaborn as sns

x_axis = segm_kmeans["Component 1"]
y_axis = segm_kmeans["Component 2"]
plt.figure(figsize=(15,15))
sns.scatterplot(x_axis,y_axis,hue = segm_kmeans["Segment"],palette = ['g','r','c','m','y'])
plt.title("Clusters by PCA Components")
plt.show()

# %%
#scatter plot of clusters
import numpy as np

data1_arr = np.array(standardized_data[cols_to_standardize])

plt.figure(figsize=(15, 15), dpi=80)
plt.scatter(data1_arr[data_reordered['cluster']==0, 0], data1_arr[data_reordered['cluster']==0, 1], s=100, c='red', label ='Cluster 1')
plt.scatter(data1_arr[data_reordered['cluster']==1, 0], data1_arr[data_reordered['cluster']==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(data1_arr[data_reordered['cluster']==2, 0], data1_arr[data_reordered['cluster']==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(data1_arr[data_reordered['cluster']==3, 0], data1_arr[data_reordered['cluster']==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(data1_arr[data_reordered['cluster']==4, 0], data1_arr[data_reordered['cluster']==4, 1], s=100, c='magenta', label ='Cluster 5')

plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], s=300, c='yellow', label = 'Centroids')
#plt.scatter(x="energy", y="danceability",data=data1_arr, s=300, c='yellow', label = 'Centroids')


plt.title('Clusters of Tracks')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
model.cluster_centers_[:, 10]
# Out:
# array([-0.36841427, -0.19008465,  2.2170856 , -0.40195942,  0.00610719])

# %%
# %matplotlib inline
import matplotlib.patches as mpatches
import seaborn as sns


data1['k-means clusters'] = kmeans.labels_

#I played with the alpha value to get a darker more readable set of points
plt.figure(figsize=(15, 10), dpi=80)
p = sns.scatterplot(x="energy", y="danceability", hue = "k-means clusters",data=data1, marker="o", alpha=1,s=200)
palette = sns.color_palette()
# class_one = mpatches.Patch(color=palette[0], label='1', alpha=0.5)
# class_two = mpatches.Patch(color=palette[1], label='2', alpha=0.5)
# class_three = mpatches.Patch(color=palette[2], label='3', alpha=0.5)
# class_four = mpatches.Patch(color=palette[3], label='4', alpha=0.5)
# class_five = mpatches.Patch(color=palette[4], label='5', alpha=0.5)
# p.legend(handles=[class_one, class_two, class_three,class_four,class_five])
#style="k-means clusters"
p

# %%
with open('new_searched_track8.pkl', 'rb') as f:
    searched = pickle.load(f)

# cols = searched.columns.tolist()
# cols = cols[-3:] + cols[:11]
# cols
# searched1 = searched[cols]
# searched1
searched_track = searched[['id',
 'name',
 'artist',
 'energy',
 'danceability',
 'acousticness',
 'instrumentalness',
 'mode',
 'liveness',
 'key',
 'tempo',
 'valence',
 'loudness',
 'speechiness']]
searched_track
# Out:
#                        id           name  artist  energy  danceability  \
# 0  2hzeDi6y5AeYhWWxmEzYyV  Truth Be Told  Toosii    0.45         0.816
#
#    acousticness  instrumentalness  mode  liveness  key   tempo  valence  \
# 0        0.0867                 0     0     0.126    1  83.507    0.425
#
#    loudness  speechiness
# 0   -11.571        0.448

# %%
# #to see what cluster song belongs to
# print(model.predict(searched_track[cols_to_standardize]))

# %%
#to display all songs of a particular cluster - to display songs related to searched song
# data_reordered[data_reordered.cluster == 1]
# Out:
#                           id                                      name  \
# 4     4Hpib09wXgD84w4uwTPnYD                                    Tap In
# 5     0qnHywpYq7D2SGMpuHEasL  Not A Rapper (feat. Lil Baby & Yo Gotti)
# 14    0uEuGO0jp4VrCmVgotvC6v                               Runnin With
# 16    2Ae2XivBS5Wql4JlS8t7VL                             No Membership
# 17    2vueU63UztXMWwW2AEyQbT                                  2 SEATER
# ...                      ...                                       ...
# 5116  74XhwnE3qbZkksZmZnr0oY                                  Solstice
# 5118  72w61pdPAAcIvR5x46awXd                                     Roses
# 5142  3nXvvnbiijvBjuDfuUODB1                               Sweet Night
# 5265  2QcJ9rR9ddplIADrrNkIBZ                                Moon Light
# 5429  7usDnd3jQUDUTVmpsaO1rc                   Pug Life - Instrumental
#
#             artist  energy  danceability  acousticness  instrumentalness  \
# 4         Saweetie   0.696         0.954       0.00576          0.000498
# 5          42 Dugg   0.715         0.888       0.12800          0.000000
# 14           LUCKI   0.475         0.896       0.00614          0.000003
# 16    Rockie Fresh   0.797         0.791       0.36400          0.000000
# 17    Justin Rarri   0.639         0.774       0.15800          0.000000
# ...            ...     ...           ...           ...               ...
# 5116       Dontcry   0.380         0.770       0.20100          0.246000
# 5118     Cantsleep   0.446         0.801       0.00254          0.060500
# 5142          KLIM   0.360         0.663       0.02070          0.905000
# 5265         Ymori   0.358         0.742       0.00255          0.228000
# 5429   Bob Village   0.902         0.758       0.07710          0.807000
#
#       mode  liveness  key    tempo  valence  loudness  speechiness  cluster
# 4        0    0.0754   10  100.036    0.432    -7.117       0.2040        1
# 5        0    0.0898    8  120.106    0.557    -3.377       0.2740        1
# 14       0    0.0891   11  131.950    0.566    -9.767       0.2260        1
# 16       0    0.0951    0  144.005    0.755    -5.109       0.0683        1
# 17       0    0.4790   11  142.959    0.723    -5.615       0.0901        1
# ...    ...       ...  ...      ...      ...       ...          ...      ...
# 5116     0    0.1530    9   81.072    0.520    -9.615       0.1010        1
# 5118     0    0.2190    6   88.045    0.627   -14.335       0.1000        1
# 5142     0    0.1410    6   86.132    0.608    -2.549       0.0670        1
# 5265     0    0.0759   10   79.945    0.668   -10.254       0.1140        1
# 5429     0    0.3670   11   94.976    0.680    -8.243       0.0560        1
#
# [1227 rows x 15 columns]

# %%
#pca example 2
correlation = data_reordered.corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col7 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row0_col11 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col0 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col3 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col5 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col6 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col8 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col9 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col10 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row1_col11 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col3 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col4 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col1 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col2 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col4 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col5 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col9 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col10 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row3_col11 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col0 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col2 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col3 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col5 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col7 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col8 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col9 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9dde9fd2_cfe6_11ea_92bb_acde48001122row4_col11 {
#             background-color:  #bad0f8;
#             color:  #0

# %%
from sklearn.preprocessing import StandardScaler
std_audio = StandardScaler().fit_transform(data_reordered[cols_to_standardize]) # normalizing the data

# %%
pca = PCA(n_components=11)
principalComponents = pca.fit_transform(std_audio)

# %%
# Plotting the variances for each PC
PC = range(1, pca.n_components_+1)
plt.bar(PC, pca.explained_variance_ratio_, color='gold')
plt.xlabel('Principal Components')
plt.ylabel('Variance %')
plt.xticks(PC)

# Putting components in a dataframe for later
PCA_components = pd.DataFrame(principalComponents)

# %%
plt.scatter(PCA_components[0], PCA_components[1], alpha=.3, color='gold')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()

# %%
inertias = []

# Creating 10 K-Mean models while varying the number of clusters (k)
for k in range(1,10):
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(PCA_components.iloc[:,:3])
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(range(1,10), inertias, '-p', color='gold')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
#plt.xticks(k)
plt.show()

# %%
model = KMeans(n_clusters=2)
model.fit(PCA_components.iloc[:,:2])

labels = model.predict(PCA_components.iloc[:,:2])
plt.scatter(PCA_components[0], PCA_components[1], c=labels)
plt.show()

# %%
#getting the labels in the new PCA Kmeans df
segm_kmeans = pd.concat([data_reordered.reset_index(drop=True)],axis=1)
#segm_kmeans.columns.values[-11:] = ["Component 1","Component 2","Component 3","Component 4","Component 5","Component 6","Component 7","Component 8","Component 9","Component 10","Component 11"]
segm_kmeans["Segment KMeans PCA"] = model.labels_
# segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2",2:"Cluster 3",3:"Cluster 4",4:"Cluster 5"})
segm_kmeans["Segment"] = segm_kmeans["Segment KMeans PCA"].map({0:"Cluster 1",1:"Cluster 2"})

segm_kmeans.head()
# Out:
#                        id                                             name  \
# 0  0DQ0uSMu01OFSxZ7Qcy7Zb  Bankrolls & Groupie Hoes (feat. Stunna 4 Vegas)
# 1  72D79mMBu1fs0DbnUU7Ecq                                  Can You Help Me
# 2  6aIARN0We3Rf0O2n20J8hp                  RNB (feat. Megan Thee Stallion)
# 3  3S5dLLX6GvTJa1bwAlN4wD                               No Suburban, Pt. 2
# 4  4Hpib09wXgD84w4uwTPnYD                                           Tap In
#
#         artist  energy  danceability  acousticness  instrumentalness  mode  \
# 0    Lil Poppa   0.583         0.833       0.01510          0.000000     0
# 1         $NOT   0.477         0.673       0.53800          0.339000     1
# 2  Young Dolph   0.684         0.888       0.02290          0.000000     1
# 3      Sheff G   0.461         0.851       0.47400          0.000000     1
# 4     Saweetie   0.696         0.954       0.00576          0.000498     0
#
#    liveness  key    tempo  valence  loudness  speechiness  cluster  \
# 0    0.1100   11   94.033    0.488    -7.942       0.2940        2
# 1    0.1350   10  179.934    0.509    -8.258       0.0705        0
# 2    0.4580    7   84.982    0.532    -6.360       0.2650        2
# 3    0.2580    8  143.974    0.620    -7.876       0.3220        2
# 4    0.0754   10  100.036    0.432    -7.117       0.2040        1
#
#    Segment KMeans PCA    Segment
# 0                   0  Cluster 1
# 1                   0  Cluster 1
# 2                   0  Cluster 1
# 3                   0  Cluster 1
# 4                   0  Cluster 1

# %%
#visualization PCA Kmeans result
# %matplotlib inline
import seaborn as sns

x_axis = PCA_components[0]
y_axis = PCA_components[1]
plt.figure(figsize=(15,15))
# sns.scatterplot(x_axis,y_axis,hue = segm_kmeans["Segment"],palette = ['g','r','b','y','m'])
sns.scatterplot(x_axis,y_axis,hue = segm_kmeans["Segment"],palette = ['g','r'])

plt.title("Clusters by PCA Components")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
std_audio = StandardScaler().fit_transform(searched_track[cols_to_standardize]) # normalizing the data
# pca = PCA(n_components=1)
principalComponents = pca.transform(std_audio)
PCA_components = pd.DataFrame(principalComponents)
print(model.predict(PCA_components.iloc[:,:2]))
# Out:
# [0]

# %%
x = segm_kmeans[segm_kmeans["Segment KMeans PCA"] == 1]
x.iloc[:, : 3]
# Out:
#                           id                        name           artist
# 7     2hzeDi6y5AeYhWWxmEzYyV               Truth Be Told           Toosii
# 41    3SbXrZOY8sp0CEWXU2u78R                  Depression     Quando Rondo
# 43    3k0LQivRnB690bkznEXI1E                 Old Streets           2KBABY
# 70    1loFoXV8Sy2cJze1YgFZwS               Honest To God            Hardo
# 80    5SwW7s3jigxgom0zORQla5    Red Light feat. Smoove’L         Casanova
# ...                      ...                         ...              ...
# 5455  1QeEuSgJieIbIcYpeND3IU                     Low Fly        TheeAgris
# 5456  3MYLwBjjdVbcj0M7kUGodd                          us           Miscél
# 5457  2PQ0EBpFcm9kaT11Zz4FAB  Flagstaff And Forest Fires   Charles Edison
# 5458  0Ueq7HrYgIzQ8wcIW6Duzg                  Levitating  Various Artists
# 5459  2mKht77kfPCde5fOCIBfSi                          V.            Houis
#
# [1379 rows x 3 columns]
